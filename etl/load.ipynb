# %%
import pandas as pd
from sqlalchemy import text
from sqlalchemy import create_engine
import pyodbc

# %%
pyodbc.drivers()
# Out:
# ['SQL Server',
#  'Microsoft Access Driver (*.mdb, *.accdb)',
#  'Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)',
#  'Microsoft Access Text Driver (*.txt, *.csv)',
#  'Microsoft Access dBASE Driver (*.dbf, *.ndx, *.mdx)',
#  'ODBC Driver 17 for SQL Server',
#  'ODBC Driver 18 for SQL Server']

# %%
conn_str = (
    "DRIVER={ODBC Driver 18 for SQL Server};"
    "SERVER=localhost;"
    "DATABASE=statsbomb;"
    "Trusted_Connection=yes;"
    "TrustServerCertificate=yes;"
)

conn = pyodbc.connect(conn_str)

# %%
cursor = conn.cursor()
cursor.execute("SELECT 1")
print(cursor.fetchone())
# Out:
# (1,)

# %%
cursor.execute("""
SELECT TABLE_SCHEMA, TABLE_NAME
FROM INFORMATION_SCHEMA.TABLES
WHERE TABLE_SCHEMA = 'dim'
""")
cursor.fetchall()
# Out:
# [('dim', 'dim_team'),
#  ('dim', 'dim_player'),
#  ('dim', 'dim_competition'),
#  ('dim', 'dim_season'),
#  ('dim', 'dim_match'),
#  ('dim', 'dim_shot_attributes'),
#  ('dim', 'dim_date')]

# %%
conn_str = (
    "DRIVER={ODBC Driver 18 for SQL Server};"
    "SERVER=localhost;"
    "DATABASE=statsbomb;"
    "Trusted_Connection=yes;"
    "TrustServerCertificate=yes;"
)

engine = create_engine(
    "mssql+pyodbc://",
    creator=lambda: pyodbc.connect(conn_str)
)

# %%
pd.read_sql("SELECT DB_NAME() AS db", engine)
# Out:
# c:\Users\Βασιλης\statsbomb_project\.venv\Lib\site-packages\pandas\io\sql.py:1648: SAWarning: Unrecognized server version info '17.0.1000.7'.  Some SQL Server features may not function properly.
#   con = self.exit_stack.enter_context(con.connect())
#           db
# 0  statsbomb

# %%
with engine.connect() as conn:
    result = conn.execute(text("SELECT 1"))
    print(result.fetchone())
# Out:
# (1,)

# %% [markdown]
# Start of csv loading

# %%
df_team = pd.read_csv(
    "../data/processed/dim_team.csv",
    dtype={
        "team_id": "int64",
        "team_name": "string"
    }
)

df_team
# Out:
#     team_id             team_name
# 0        22        Leicester City
# 1        28       AFC Bournemouth
# 2        27  West Bromwich Albion
# 3        41            Sunderland
# 4        37      Newcastle United
# 5        59           Aston Villa
# 6        29               Everton
# 7        31        Crystal Palace
# 8        23               Watford
# 9         1               Arsenal
# 10       24             Liverpool
# 11       38     Tottenham Hotspur
# 12       36       Manchester City
# 13       56          Norwich City
# 14       33               Chelsea
# 15       30            Stoke City
# 16       39     Manchester United
# 17       40       West Ham United
# 18       26          Swansea City
# 19       25           Southampton

# %%
with engine.begin() as conn:
    conn.execute(text("DELETE FROM dim.dim_team"))

# %%
df_team.to_sql(
    name="dim_team",
    schema="dim",
    con=engine,
    if_exists="append",
    index=False,
    method="multi"
)
# Out:
# 20

# %% [markdown]
# Dim player

# %%
df_player = pd.read_csv(
    "../data/processed/dim_player.csv",
    dtype={
        "player_id": "int64",
        "player_name": "string",
        "position_name": "string"
    }
)
# Out:
#      player_id                      player_name            position_name
# 0         2956          Bertrand Isidore Traoré           Center Forward
# 1         2966               Stéphane Sessègnon           Right Midfield
# 2         2988                    Memphis Depay                Left Wing
# 3         3037          Mousa Sidi Yaya Dembélé  Left Defensive Midfield
# 4         3041                     Ciaran Clark         Left Center Back
# ..         ...                              ...                      ...
# 544      75899                      Kevin Toner         Left Center Back
# 545     128703  Dionatan do Nascimento Teixeira         Left Center Back
# 546     128704                 Emmanuel Emenike           Center Forward
# 547     129558                     Tony Hibbert               Right Back
# 548     129559                   Rees Greenwood            Left Midfield
#
# [549 rows x 3 columns]

# %%
with engine.begin() as conn:
    conn.execute(text("DELETE FROM dim.dim_player"))

# %%
df_player.to_sql(
    name="dim_player",
    schema="dim",
    con=engine,
    if_exists="append",
    index=False,
    method="multi"
)
# Out:
# 549

# %% [markdown]
# dim_competition

# %%
df_comp = pd.read_csv(
    "../data/processed/dim_competition.csv",
    dtype={
        "competition_id": "int64",
        "competition_name": "string",
        "country_name": "string"
    }
)

df_comp
# Out:
#    competition_id competition_name country_name
# 0               2   Premier League      England

# %%
with engine.begin() as conn:
    conn.execute(text("DELETE FROM dim.dim_competition"))

# %%
df_comp.to_sql(
    name="dim_competition",
    schema="dim",
    con=engine,
    if_exists="append",
    index=False,
    method="multi"
)
# Out:
# 1

# %% [markdown]
# dim_season

# %%
df_season = pd.read_csv(
    "../data/processed/dim_season.csv",
    dtype={
        "season_id": "int64",
        "season_name": "string"
    }
)

df_season
# Out:
#    season_id season_name
# 0         27   2015/2016
# 1         44   2003/2004

# %%
with engine.begin() as conn:
    conn.execute(text("DELETE FROM dim.dim_season"))

# %%
df_season.to_sql(
    name="dim_season",
    schema="dim",
    con=engine,
    if_exists="append",
    index=False,
    method="multi"
)
# Out:
# 2

# %% [markdown]
# dim_match

# %%
df_match = pd.read_csv(
    "../data/processed/dim_match.csv",
    dtype={
        "match_id": "int64",
        "match_date": "string",
        "kick_off": "string",
        "home_team_name": "string",
        "away_team_name": "string",
        "home_score": "int64",
        "away_score": "int64",
        "match_week": "int64"
    }
)

df_match.head()
# Out:
#    match_id  match_date      kick_off        home_team_name   away_team_name  \
# 0   3754058  2016-01-02  16:00:00.000        Leicester City  AFC Bournemouth
# 1   3754245  2015-10-17  16:00:00.000  West Bromwich Albion       Sunderland
# 2   3754136  2015-12-19  18:30:00.000      Newcastle United      Aston Villa
# 3   3754037  2016-04-30  16:00:00.000               Everton  AFC Bournemouth
# 4   3754039  2016-02-13  16:00:00.000        Crystal Palace          Watford
#
#    home_score  away_score  match_week
# 0           0           0          20
# 1           1           0           9
# 2           1           1          17
# 3           2           1          36
# 4           1           2          26

# %%
df_match["match_date"] = pd.to_datetime(df_match["match_date"]).dt.date
df_match["kick_off"] = pd.to_datetime(df_match["kick_off"]).dt.time
# Out:
# C:\Users\Βασιλης\AppData\Local\Temp\ipykernel_19520\423445720.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_match["kick_off"] = pd.to_datetime(df_match["kick_off"]).dt.time

# %%
df_team = pd.read_sql(
    "SELECT team_key, team_name FROM dim.dim_team",
    engine
)

df_team
# Out:
#     team_key             team_name
# 0          1        Leicester City
# 1          2       AFC Bournemouth
# 2          3  West Bromwich Albion
# 3          4            Sunderland
# 4          5      Newcastle United
# 5          6           Aston Villa
# 6          7               Everton
# 7          8        Crystal Palace
# 8          9               Watford
# 9         10               Arsenal
# 10        11             Liverpool
# 11        12     Tottenham Hotspur
# 12        13       Manchester City
# 13        14          Norwich City
# 14        15               Chelsea
# 15        16            Stoke City
# 16        17     Manchester United
# 17        18       West Ham United
# 18        19          Swansea City
# 19        20           Southampton

# %%
df_match = df_match.merge(
    df_team,
    left_on="home_team_name",
    right_on="team_name",
    how="left"
).rename(columns={"team_key": "home_team_key"}).drop(columns=["team_name"])

# %%
df_match = df_match.merge(
    df_team,
    left_on="away_team_name",
    right_on="team_name",
    how="left"
).rename(columns={"team_key": "away_team_key"}).drop(columns=["team_name"])

# %%
df_match[["home_team_name", "home_team_key", "away_team_name", "away_team_key"]].head()
# Out:
#          home_team_name  home_team_key   away_team_name  away_team_key
# 0        Leicester City              1  AFC Bournemouth              2
# 1  West Bromwich Albion              3       Sunderland              4
# 2      Newcastle United              5      Aston Villa              6
# 3               Everton              7  AFC Bournemouth              2
# 4        Crystal Palace              8          Watford              9

# %%
comp_key = pd.read_sql(
    "SELECT competition_key FROM dim.dim_competition WHERE competition_name = 'Premier League'",
    engine
).iloc[0, 0]

season_key = pd.read_sql(
    "SELECT season_key FROM dim.dim_season WHERE season_name = '2015/2016'",
    engine
).iloc[0, 0]

df_match["competition_key"] = comp_key
df_match["season_key"] = season_key

# %%
df_match_final = df_match[[
    "match_id",
    "match_date",
    "kick_off",
    "competition_key",
    "season_key",
    "home_team_key",
    "away_team_key",
    "home_team_name",
    "away_team_name",
    "home_score",
    "away_score",
    "match_week"
]]

# %%
df_match_final
# Out:
#      match_id  match_date  kick_off  competition_key  season_key  \
# 0     3754058  2016-01-02  16:00:00                1           1
# 1     3754245  2015-10-17  16:00:00                1           1
# 2     3754136  2015-12-19  18:30:00                1           1
# 3     3754037  2016-04-30  16:00:00                1           1
# 4     3754039  2016-02-13  16:00:00                1           1
# ..        ...         ...       ...              ...         ...
# 375   3754020  2015-08-17  21:00:00                1           1
# 376   3754267  2015-08-15  16:00:00                1           1
# 377   3754141  2015-08-09  14:30:00                1           1
# 378   3754128  2015-08-08  16:00:00                1           1
# 379   3754078  2015-08-08  18:30:00                1           1
#
#      home_team_key  away_team_key        home_team_name        away_team_name  \
# 0                1              2        Leicester City       AFC Bournemouth
# 1                3              4  West Bromwich Albion            Sunderland
# 2                5              6      Newcastle United           Aston Villa
# 3                7              2               Everton       AFC Bournemouth
# 4                8              9        Crystal Palace               Watford
# ..             ...            ...                   ...                   ...
# 375             11              2             Liverpool       AFC Bournemouth
# 376              9              3               Watford  West Bromwich Albion
# 377             10             18               Arsenal       West Ham United
# 378              2              6       AFC Bournemouth           Aston Villa
# 379             15             19               Chelsea          Swansea City
#
#      home_score  away_score  match_week
# 0             0           0          20
# 1             1           0           9
# 2             1           1          17
# 3             2           1          36
# 4             1           2          26
# ..          ...         ...         ...
# 375           1           0           2
# 376           0           0           2
# 377           0           2           1
# 378           0           1           1
# 379           2           2           1
#
# [380 rows x 12 columns]

# %%
with engine.begin() as conn:
    conn.execute(text("DELETE FROM dim.dim_match"))

# %%
df_match_final.to_sql(
    name="dim_match",
    schema="dim",
    con=engine,
    if_exists="append",
    index=False,
    method="multi",
    chunksize=100
)
# Out:
# 380

# %% [markdown]
# dim_shots

# %%
df_shot = pd.read_csv(
    "../data/processed/fact_shot.csv",
    dtype={
        "shot_outcome": "string",
        "shot_body_part": "string",
        "shot_type": "string",
        "shot_technique": "string",
        "shot_first_time": "boolean",
        "shot_one_on_one": "boolean"
    }
)

df_shot.head()
# Out:
#                                event_id  shot_statsbomb_xg shot_outcome  \
# 0  72596ffe-393e-4a75-82c6-5fb82ae36d4d           0.020838      Blocked
# 1  b2bae775-5dd8-45bf-9b84-191c7849f707           0.034462      Blocked
# 2  7c4227e5-0759-4633-93ea-bbbe291bbd72           0.035481        Off T
# 3  8e3a6f10-64e4-49bf-a157-16b15b552713           0.383711        Off T
# 4  3a5364b3-0b99-4271-a451-0a3033ad195d           0.036740      Wayward
#
#   shot_body_part  shot_type shot_technique  shot_first_time  shot_one_on_one  \
# 0     Right Foot  Open Play         Normal            False            False
# 1     Right Foot  Open Play         Normal            False            False
# 2      Left Foot  Open Play  Overhead Kick             True            False
# 3           Head  Open Play         Normal            False            False
# 4     Right Foot  Open Play    Half Volley            False            False
#
#    end_x  end_y  end_z
# 0  109.7   30.1    NaN
# 1  114.5   52.6    NaN
# 2  120.0   43.3    3.6
# 3  120.0   46.0    1.2
# 4  103.9   40.1    NaN

# %%
shot_attr_cols = [
    "shot_outcome",
    "shot_body_part",
    "shot_type",
    "shot_technique",
    "shot_first_time",
    "shot_one_on_one"
]

df_attr = df_shot[shot_attr_cols]

# %%
df_attr["shot_first_time"] = df_attr["shot_first_time"].astype("int")
df_attr["shot_one_on_one"] = df_attr["shot_one_on_one"].astype("int")
# Out:
# C:\Users\Βασιλης\AppData\Local\Temp\ipykernel_19520\3454193309.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_attr["shot_first_time"] = df_attr["shot_first_time"].astype("int")
# C:\Users\Βασιλης\AppData\Local\Temp\ipykernel_19520\3454193309.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_attr["shot_one_on_one"] = df_attr["shot_one_on_one"].astype("int")

# %%
df_attr = df_attr.drop_duplicates().reset_index(drop=True)

df_attr
# Out:
#       shot_outcome shot_body_part  shot_type shot_technique  shot_first_time  \
# 0          Blocked     Right Foot  Open Play         Normal                0
# 1            Off T      Left Foot  Open Play  Overhead Kick                1
# 2            Off T           Head  Open Play         Normal                0
# 3          Wayward     Right Foot  Open Play    Half Volley                0
# 4             Post     Right Foot  Open Play         Normal                0
# ..             ...            ...        ...            ...              ...
# 225           Post      Left Foot  Open Play    Half Volley                0
# 226        Wayward      Left Foot  Open Play       Backheel                1
# 227        Wayward      Left Foot  Open Play  Overhead Kick                0
# 228           Goal      Left Foot  Open Play       Backheel                1
# 229  Saved to Post     Right Foot  Open Play         Volley                1
#
#      shot_one_on_one
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  1
# ..               ...
# 225                0
# 226                0
# 227                0
# 228                0
# 229                0
#
# [230 rows x 6 columns]

# %%
with engine.begin() as conn:
    conn.execute(text("DELETE FROM dim.dim_shot_attributes"))

# %%
df_attr.to_sql(
    name="dim_shot_attributes",
    schema="dim",
    con=engine,
    if_exists="append",
    index=False,
    method="multi",
    chunksize=100
)
# Out:
# 230

# %% [markdown]
# dim_pass_attributes

# %%
df_pass = pd.read_csv(
    "../data/processed/fact_pass.csv",
    dtype={
        "pass_height": "string",
        "pass_type": "string",
        "pass_outcome": "string"
    }
)
# Out:
#                                event_id  end_x  end_y  pass_length  \
# 0  2ca23eea-a984-47e4-8243-8f00880ad1c9   60.4   43.6     3.551056
# 1  0fee7719-7e69-49c5-be81-3f2b77da604e   48.0   41.7    12.544720
# 2  6362aa69-892f-4d11-8644-21a680ea7c66   37.5   76.1    35.966790
# 3  56da36e4-8b0d-4596-ba46-1d944c3d3f04   27.4   58.1    19.345800
# 4  bcfea2e3-9736-4975-be28-ef2c9d693fa7   35.1   77.8    15.890248
#
#    pass_angle  pass_height pass_type pass_outcome pass_recipient
# 0    1.740575  Ground Pass  Kick Off         <NA>    Joshua King
# 1   -2.989549  Ground Pass      <NA>         <NA>  Andrew Surman
# 2    1.867047  Ground Pass      <NA>         <NA>     Adam Smith
# 3   -2.120081  Ground Pass      <NA>         <NA>  Simon Francis
# 4    1.064920  Ground Pass      <NA>         <NA>     Adam Smith

# %%
df_attr = df_pass[[
    "pass_height",
    "pass_type",
    "pass_outcome"
]].drop_duplicates().reset_index(drop=True)

# %%
with engine.begin() as conn:
    conn.execute(text("DELETE FROM dim.dim_pass_attributes"))

# %%
df_attr.to_sql(
    name="dim_pass_attributes",
    schema="dim",
    con=engine,
    if_exists="append",
    index=False,
    method="multi",
    chunksize=100
)
# Out:
# 102

# %% [markdown]
# FACT_EVENT

# %%
df_event = pd.read_csv(
    "../data/processed/fact_event.csv",
    dtype={
        "event_id": "string",
        "match_id": "int64",
        "team_id": "int64",
        "player_id": "Int64",   
        "period": "int64",
        "minute": "int64",
        "second": "int64",
        "event_type": "string",
        "event_category": "string",
        "possession": "int64",
        "possession_team_id": "int64",
        "under_pressure": "boolean",
        "x": "float",
        "y": "float",
        "is_pass": "boolean",
        "is_shot": "boolean",
        "is_carry": "boolean",
        "is_pressure": "boolean"
    }
)

# %%
bool_cols = [
    "under_pressure",
    "is_pass",
    "is_shot",
    "is_pressure",
    "is_carry"
]

for c in bool_cols:
    df_event[c] = df_event[c].astype("int")

# %%
df_match = pd.read_sql(
    "SELECT match_key, match_id FROM dim.dim_match",
    engine
)

df_event = df_event.merge(
    df_match,
    on="match_id",
    how="left"
)

# %%
df_team = pd.read_sql(
    "SELECT team_key, team_id FROM dim.dim_team",
    engine
)

df_event = df_event.merge(
    df_team,
    on="team_id",
    how="left"
)

df_event = df_event.merge(
    df_team.rename(columns={
        "team_key": "possession_team_key",
        "team_id": "possession_team_id"
    }),
    on="possession_team_id",
    how="left"
)

# %%
df_player = pd.read_sql(
    "SELECT player_key, player_id FROM dim.dim_player",
    engine
)

df_event = df_event.merge(
    df_player,
    on="player_id",
    how="left"
)

# %%
df_event_final = df_event[[
    "event_id",
    "match_key",
    "team_key",
    "player_key",
    "period",
    "minute",
    "second",
    "event_type",
    "event_category",
    "possession",
    "possession_team_key",
    "under_pressure",
    "x",
    "y",
    "is_pass",
    "is_shot",
    "is_pressure",
    "is_carry",
]]

# %%
with engine.begin() as conn:
    conn.execute(text("DELETE FROM fact.fact_event"))

# %%
df_event_final.to_sql(
    name="fact_event",
    schema="fact",
    con=engine,
    if_exists="append",
    index=False,
    method="multi",
    chunksize=100
)
# Out:
# 1313783

# %% [markdown]
# fact_shot

# %%
df_shot = pd.read_csv(
    "../data/processed/fact_shot.csv",
    dtype={
        "event_id": "string",
        "shot_statsbomb_xg": "float",
        "shot_outcome": "string",
        "shot_body_part": "string",
        "shot_type": "string",
        "shot_technique": "string",
        "shot_first_time": "boolean",
        "shot_one_on_one": "boolean",
        "end_x": "float",
        "end_y": "float",
        "end_z": "float"
    }
)

# %%
df_shot["shot_first_time"] = df_shot["shot_first_time"].astype("int")
df_shot["shot_one_on_one"] = df_shot["shot_one_on_one"].astype("int")

# %%
df_shot_attr = pd.read_sql(
    """
    SELECT
        shot_attr_key,
        shot_outcome,
        shot_body_part,
        shot_type,
        shot_technique,
        shot_first_time,
        shot_one_on_one
    FROM dim.dim_shot_attributes
    """,
    engine
)

df_shot = df_shot.merge(
    df_shot_attr,
    on=[
        "shot_outcome",
        "shot_body_part",
        "shot_type",
        "shot_technique",
        "shot_first_time",
        "shot_one_on_one"
    ],
    how="left"
)

# %%
df_event = pd.read_sql(
    """
    SELECT
        event_id,
        event_key,
        match_key,
        team_key,
        player_key
    FROM fact.fact_event
    """,
    engine
)

df_shot = df_shot.merge(
    df_event,
    on="event_id",
    how="left"
)

# %%
df_shot_final = df_shot[[
    "event_id",
    "event_key",
    "match_key",
    "team_key",
    "player_key",
    "shot_attr_key",
    "shot_statsbomb_xg",
    "end_x",
    "end_y",
    "end_z"
]]

# %%
with engine.begin() as conn:
    conn.execute(text("DELETE FROM fact.fact_shot"))

# %%
df_shot_final.to_sql(
    name="fact_shot",
    schema="fact",
    con=engine,
    if_exists="append",
    index=False,
    method="multi",
    chunksize=100
)
# Out:
# 9908

# %%
pd.read_sql(
    "SELECT TOP 10 fs.event_id, fe.event_type, fs.shot_statsbomb_xg FROM fact.fact_shot fs JOIN fact.fact_event fe ON fs.event_key = fe.event_key",
    engine
)
# Out:
#                                event_id event_type  shot_statsbomb_xg
# 0  7db239ff-9ff2-4e31-bb58-acb3a1cba52e       Shot           0.245253
# 1  3ca8bc18-6083-4d5a-afc1-4dc20de42e43       Shot           0.042902
# 2  ae5dfce5-95e6-47b1-b2e3-abc11d7d59f2       Shot           0.012095
# 3  39ba03e1-5445-4735-a38e-c0b8330d9883       Shot           0.023960
# 4  4a791b58-400d-412b-89e9-7d6a8dc6d454       Shot           0.044721
# 5  a2904741-25d0-4824-aa20-1aed74d26389       Shot           0.028252
# 6  0deef0c6-856b-469c-bfaa-15264d794cd2       Shot           0.020842
# 7  ca9b925c-13c5-4a4c-bcbb-d5c48ed89d91       Shot           0.039429
# 8  24f7f6d4-bbb0-45da-8414-2cb58af7d8f4       Shot           0.008613
# 9  a9326c0b-1e10-43f1-8d0d-de63ca8a6114       Shot           0.057364

# %% [markdown]
# fact_pass

# %%
df_pass = pd.read_csv(
    "../data/processed/fact_pass.csv",
    dtype={
        "event_id": "string",
        "end_x": "float",
        "end_y": "float",
        "pass_length": "float",
        "pass_angle": "float",
        "pass_height": "string",
        "pass_type": "string",
        "pass_outcome": "string",
        "pass_recipient": "string"
    }
)

# %%
df_pass_attr = pd.read_sql(
    """
    SELECT
        pass_attr_key,
        pass_height,
        pass_type,
        pass_outcome
    FROM dim.dim_pass_attributes
    """,
    engine
)

df_pass = df_pass.merge(
    df_pass_attr,
    on=["pass_height", "pass_type", "pass_outcome"],
    how="left"
)

# %%
df_event = pd.read_sql(
    """
    SELECT
        event_id,
        event_key,
        match_key,
        team_key,
        player_key AS passer_player_key
    FROM fact.fact_event
    WHERE is_pass = 1
    """,
    engine
)

df_pass = df_pass.merge(
    df_event,
    on="event_id",
    how="left"
)

# %%
df_players = pd.read_sql(
    "SELECT player_key, player_name FROM dim.dim_player",
    engine
)

df_pass = df_pass.merge(
    df_players,
    left_on="pass_recipient",
    right_on="player_name",
    how="left"
).rename(columns={"player_key": "receiver_player_key"}).drop(columns=["player_name"])

# %%
df_pass[["pass_recipient", "receiver_player_key"]]
# Out:
#                        pass_recipient  receiver_player_key
# 0                         Joshua King                 83.0
# 1                       Andrew Surman                 81.0
# 2                          Adam Smith                327.0
# 3                       Simon Francis                176.0
# 4                          Adam Smith                327.0
# ...                               ...                  ...
# 368614           Gylfi Þór Sigurðsson                  NaN
# 368615   Radamel Falcao García Zárate                  NaN
# 368616                           <NA>                  NaN
# 368617  Éderzito António Macedo Lopes                  NaN
# 368618                  Jonjo Shelvey                 11.0
#
# [368619 rows x 2 columns]

# %%
df_pass_final = df_pass[[
    "event_id",
    "event_key",
    "match_key",
    "team_key",
    "passer_player_key",
    "receiver_player_key",
    "pass_attr_key",
    "end_x",
    "end_y",
    "pass_length",
    "pass_angle"
]]

# %%
with engine.begin() as conn:
    conn.execute(text("DELETE FROM fact.fact_pass"))

# %%
df_pass_final.to_sql(
    name="fact_pass",
    schema="fact",
    con=engine,
    if_exists="append",
    index=False,
    method="multi",
    chunksize=100
)
# Out:
# 368619
